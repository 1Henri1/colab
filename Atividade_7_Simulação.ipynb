# %% [markdown]
# <a href="https://colab.research.google.com/github/1Henri1/colab/blob/main/Atividade_7_Simula%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Bases Computacionais da Ciência - Raphael Y. de Camargo - 2024.2
#
# ## Lista 7 - Entregar até o dia 28/08

# %% [markdown]
# ### Problema 1: Simulação de Jogo de Azar
#
# Implemente uma simulação para o jogo de azar feito em aula, com 2 opções de número com mesma probabilidade, e onde o jogador recebe o mesmo valor que apostou quando acerta a jogada.
#
# O jogador sempre aposta 10 reais no número 1. Ele começa com 100 reais e para de jogar quando atingir 200 reais ou perder todo o dinheiro. Realize a simulação e exiba quantas rodadas foram necessárias para o jogador atingir um dos dois objetivos e qual foi o resultado.

# %%
import random as rd
apost = 10
saldo = 100

while saldo>0 and saldo<200:
  sort = rd.randint(1,2)
  if sort == 1:
    print("ganhou $10")
    saldo = saldo+apost
  else:
    print("perdeu $10")
    saldo = saldo-apost
  print(f"agora tem ${saldo}")

if saldo <=0:
  print("voce perdeu")
else:
  print("voce ganhou")
# Out:
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# ganhou $10
# agora tem $110
# ganhou $10
# agora tem $120
# ganhou $10
# agora tem $130
# perdeu $10
# agora tem $120
# ganhou $10
# agora tem $130
# perdeu $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# perdeu $10
# agora tem $110
# perdeu $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# perdeu $10
# agora tem $90
# perdeu $10
# agora tem $80
# ganhou $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# perdeu $10
# agora tem $90
# perdeu $10
# agora tem $80
# perdeu $10
# agora tem $70
# perdeu $10
# agora tem $60
# ganhou $10
# agora tem $70
# ganhou $10
# agora tem $80
# perdeu $10
# agora tem $70
# ganhou $10
# agora tem $80
# perdeu $10
# agora tem $70
# perdeu $10
# agora tem $60
# perdeu $10
# agora tem $50
# ganhou $10
# agora tem $60
# perdeu $10
# agora tem $50
# perdeu $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# ganhou $10
# agora tem $50
# ganhou $10
# agora tem $60
# ganhou $10
# agora tem $70
# ganhou $10
# agora tem $80
# ganhou $10
# agora tem $90
# perdeu $10
# agora tem $80
# perdeu $10
# agora tem $70
# ganhou $10
# agora tem $80
# perdeu $10
# agora tem $70
# perdeu $10
# agora tem $60
# perdeu $10
# agora tem $50
# ganhou $10
# agora tem $60
# ganhou $10
# agora tem $70
# ganhou $10
# agora tem $80
# ganhou $10
# agora tem $90
# ganhou $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# perdeu $10
# agora tem $80
# perdeu $10
# agora tem $70
# ganhou $10
# agora tem $80
# ganhou $10
# agora tem $90
# ganhou $10
# agora tem $100
# ganhou $10
# agora tem $110
# perdeu $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# perdeu $10
# agora tem $80
# ganhou $10
# agora tem $90
# ganhou $10
# agora tem $100
# perdeu $10
# agora tem $90
# ganhou $10
# agora tem $100
# ganhou $10
# agora tem $110
# ganhou $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# ganhou $10
# agora tem $130
# perdeu $10
# agora tem $120
# ganhou $10
# agora tem $130
# perdeu $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# perdeu $10
# agora tem $110
# ganhou $10
# agora tem $120
# ganhou $10
# agora tem $130
# ganhou $10
# agora tem $140
# ganhou $10
# agora tem $150
# ganhou $10
# agora tem $160
# perdeu $10
# agora tem $150
# perdeu $10
# agora tem $140
# ganhou $10
# agora tem $150
# ganhou $10
# agora tem $160
# ganhou $10
# agora tem $170
# perdeu $10
# agora tem $160
# perdeu $10
# agora tem $150
# ganhou $10
# agora tem $160
# ganhou $10
# agora tem $170
# perdeu $10
# agora tem $160
# perdeu $10
# agora tem $150
# perdeu $10
# agora tem $140
# perdeu $10
# agora tem $130
# ganhou $10
# agora tem $140
# perdeu $10
# agora tem $130
# perdeu $10
# agora tem $120
# perdeu $10
# agora tem $110
# perdeu $10
# agora tem $100
# perdeu $10
# agora tem $90
# perdeu $10
# agora tem $80
# ganhou $10
# agora tem $90
# perdeu $10
# agora tem $80
# perdeu $10
# agora tem $70
# perdeu $10
# agora tem $60
# ganhou $10
# agora tem $70
# perdeu $10
# agora tem $60
# ganhou $10
# agora tem $70
# perdeu $10
# agora tem $60
# perdeu $10
# agora tem $50
# perdeu $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# ganhou $10
# agora tem $50
# perdeu $10
# agora tem $40
# ganhou $10
# agora tem $50
# ganhou $10
# agora tem $60
# ganhou $10
# agora tem $70
# ganhou $10
# agora tem $80
# perdeu $10
# agora tem $70
# perdeu $10
# agora tem $60
# perdeu $10
# agora tem $50
# perdeu $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# ganhou $10
# agora tem $50
# perdeu $10
# agora tem $40
# ganhou $10
# agora tem $50
# perdeu $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# perdeu $10
# agora tem $10
# ganhou $10
# agora tem $20
# ganhou $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# ganhou $10
# agora tem $50
# perdeu $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# perdeu $10
# agora tem $20
# perdeu $10
# agora tem $10
# ganhou $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# ganhou $10
# agora tem $30
# ganhou $10
# agora tem $40
# perdeu $10
# agora tem $30
# perdeu $10
# agora tem $20
# perdeu $10
# agora tem $10
# ganhou $10
# agora tem $20
# ganhou $10
# agora tem $30
# perdeu $10
# agora tem $20
# perdeu $10
# agora tem $10
# ganhou $10
# agora tem $20
# perdeu $10
# agora tem $10
# ganhou $10
# agora tem $20
# perdeu $10
# agora tem $10
# perdeu $10
# agora tem $0
# voce perdeu

# %% [markdown]
# ### Problema 2: Estatísticas de Jogo de Azar
#
# Realize 1.000 simulações do jogo descrito anteriormente e imprima: (i) A média do número de rodadas necessárias para que o jogador atinja um dos objetivos e (ii) A porcentagem de vezes em que o jogador conseguiu alcançar os 200 reais.
#
# Em seguida, realize o mesmo procedimento, mas considerando que o operador do jogo fica com 2% do valor ganho em cada rodada, isto é, ao invés de receber 10 reais ao acertar o número, ele recebe 9,80.

# %%
import random as rd
apost = 10
vito = 0
derro = 0
rodad = 0

for i in range(0,1000):
  saldo = 100
  while saldo>0 and saldo<200:
    sort = rd.randint(1,2)
    if sort == 1:
      saldo = saldo+apost
      rodad +=1
    else:
      saldo = saldo-apost
      rodad +=1
  if saldo <=0:
    derro +=1
  else:
    vito +=1
print("primeiro caso")
print(f"foram {vito} vitórias e {derro} derrotas")
print(f"a média de rodadas para atingir um dos objetivos é {rodad/1000}")
print(f"a porcentagem de vitórias é {vito/1000*100}%")


rodad = 0
vito = 0
derro = 0
for i in range(0,1000):
  saldo = 100
  while saldo>0 and saldo<200:
    sort = rd.randint(1,2)
    if sort == 1:
      saldo = saldo+apost-0.2
      rodad +=1
    else:
      saldo = saldo-apost
      rodad +=1
  if saldo <=0:
    derro +=1
  else:
    vito +=1
print("\nsegundo caso")
print(f"foram {vito} vitórias e {derro} derrotas")
print(f"a média de rodadas para atingir um dos objetivos é {rodad/1000}")
print(f"a porcentagem de vitórias é {vito/1000*100}%")
# Out:
# primeiro caso
# foram 485 vitórias e 515 derrotas
# a média de rodadas para atingir um dos objetivos é 101.41
# a porcentagem de vitórias é 48.5%
#
# segundo caso
# foram 446 vitórias e 554 derrotas
# a média de rodadas para atingir um dos objetivos é 118.618
# a porcentagem de vitórias é 44.6%

# %% [markdown]
# ### Problema 3:
#
# Você tem um quadrado de lado `k` unidades, onde o calor de `k` é lido do teclado, e um círculo inscrito dentro desse quadrado (ou seja, o círculo toca os lados do quadrado). Usando o método de Monte Carlo, estime a área do círculo. Para isso, gere pontos aleatórios dentro do quadrado e determine a proporção desses pontos que caem dentro do círculo. Com base nessa proporção, estime a área do círculo.

# %%
k = int(input("digite a area do circulo"))
r = k/2
ncirc = 0
n = 0
for i in range(0,1000):
  x = rd.uniform(0,k)
  y = rd.uniform(0,k)
  dist = ((x-r)**2 + (y-r)**2)**0.5
  if dist <= r:
    ncirc +=1
    n +=1
  else:
    n +=1
pi = 4*ncirc/n
area = pi*r**2
print("pi é",pi)
print(f"a area do circulo é {area}")
# Out:
# digite a area do circulo2
# pi é 3.164
# a area do circulo é 3.164

# %% [markdown]
# ### Problema 4
#
# No jogo de tabuleiro War, um jogador pode atacar o território do outro com suas tropas. O atacante pode atacar com 1, 2 ou 3 tropas e o defensor pode se defender com 1, 2 ou 3 tropas.
#
# No caso mais simples, tanto o atacante quanto o defensor possuem 1 tropa. Neste caso, o atacante e o defensor jogam um dado de 6 faces cada. Se o atacante tirar o maior número, ele vence. Se o defensor tirar um número maior ou igual ao atacante, o defensor vence.
#
# Agora vamos simular o caso do ataque e defensor terem 2 tropas cada. Neste caso, o atacante e o defensor jogam 2 dados cada.
#
# Você deve então comparar:
#
# (i) o dado de maior valor obtido pelo atacante e o de maior valor obtido pelo defensor. Isso gerará o vencedor para uma das tropas
#
# (ii) o dado de menor valor obtido pelo atacante e o de menor valor obtido pelo defensor. Isso gerará o vencedor para a segunda tropa
#
# Exemplo:
#
# ataque: 6 2
#
# defesa: 2 5
#
# Neste caso, iremos juntar os dados de valores 6 e 5, de modo que o atacante venceu a primeira batalha. Em seguida, comparamos os valores 2 e 2, de modo que a defesa venceu a segunda batalha. No final, o ataque perdeu uma tropa e a defesa perdeu 1 tropa.
#
# Escreva um programa que simula o caso do ataque e defesa com 2 tropas cada. Ele deve devolver quantas tropas cada jogador perdeu (ataque, defesa).

# %%
from ast import Invert
import random as rd
vitoata = 0
vitodef = 0
for i in range(0,2):
  sortata = [rd.randint(1,6),rd.randint(1,6)]
  sortdef = [rd.randint(1,6),rd.randint(1,6)]
sortata.sort()
sortdef.sort()
if sortata[1] > sortdef[1]:
  vitoata+=1
else:
  vitodef+=1
if sortata[0] > sortdef[0]:
  vitoata+=1
else:
  vitodef+=1
print(f"o atacante tirou os numeros{sortata}\no defensor tirou os numeros{sortdef}" )
print(f"o atacante perdeu {vitodef} tropas, o defensor perdeu {vitoata} tropas")
# Out:
# o atacante tirou os numeros[2, 5]
# o defensor tirou os numeros[3, 6]
# o atacante perdeu 2 tropas, o defensor perdeu 0 tropas

# %% [markdown]
# ### Problema 5
#
# Você está simulando um jogo RPG, onde 2 personagens X e Y se revezam em uma batalha. Cada um possui 3 atributos: habilidade de ataque (entre 2 e 10), de defesa (entre 2 e 10) e vida (entre 10 e 20). Estes atributos são lidos a partir do teclado.
#
# Na primeira rodada o personagem X ataca, na segunda o Y ataca e os ataques seguem alternados até que um dos personagens seja derrotado.
#
# O personagem que ataca A deve jogar um dado de 10 faces. Se o valor sorteado `dado` for menor do que sua habilidade de ataque, ele acertou o ataque. Neste caso, o outro personagem tentará se defender jogando um dado. Se o valor sorteado for menor do que sua habilidade de defesa, ele conseguiu se defender.
#
# Caso o ataque seja bem sucedido, isto é, o atacante acertou o ataque e o defensor errou a defesa, deve ser calculado qual foi o dano de ataque. Este dano será igual à diferença entre o valor que o atacante tirou em seus dados durante o ataque (`dado`) e sua habilidade.
#
# Você deve repetir o processo até que um dos personagens fique com vida zero. Em cada rodada, imprima qual o personagem que atacou, se ele e o defensor acertaram o ataque e defesa, o dano causado (se aplicável) e a vida restante para o personagem que foi ferido.
#
# O programa deve imprimir qual o personagem vencedor "X" ou "Y", e qual a vida restante do vencedor.

# %%
atax = int(input("digite seu ataque de 2 a 10:"))
defx = int(input("digite sua defesa de 2 a 10:"))
vidax = int(input("digite sua vida de 10 a 20:"))
atay = int(input("digite seu ataque de 2 a 10:"))
defy = int(input("digite sua defesa de 2 a 10:"))
viday = int(input("digite sua vida de 10 a 20:"))

while vidax > 0 and viday> 0:
  dadox = rd.randint(1,10)
  if dadox < atax:
    dadoy = rd.randint(1,10)
    if dadoy < defy:
      print("y defendeu o ataque")
    else:
      dano = atax - dadox
      print(f"x acertou o ataque e causou {dano} de dano" )
      viday = viday - dano
      print(f"y ficou com: {viday} de vida")
  else:
    print("x errou o ataque")

  if viday>0:
    dadoy = rd.randint(1,10)
    if dadoy < atay:
      dadox = rd.randint(1,10)
      if dadox < defx:
        print("x defendeu o ataque")
      else:
        dano = atay - dadoy
        print(f"y acertou o ataque e causou {dano} de dano" )
        vidax = vidax - dano
        print(f"x ficou com: {vidax} de vida")
    else:
      print("y errou o ataque")
if vidax>0:
  print(f"x venceu com {vidax} de vida")
else:
  print(f"y venceu com {viday} de vida")
# Out:
# digite seu ataque de 2 a 10:10
# digite sua defesa de 2 a 10:10
# digite sua vida de 10 a 20:20
# digite seu ataque de 2 a 10:10
# digite sua defesa de 2 a 10:10
# digite sua vida de 10 a 20:20
# y defendeu o ataque
# x defendeu o ataque
# x errou o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y acertou o ataque e causou 5 de dano
# x ainda tem: 15 de vida
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# x errou o ataque
# y acertou o ataque e causou 5 de dano
# x ainda tem: 10 de vida
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y acertou o ataque e causou 4 de dano
# x ainda tem: 6 de vida
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# x acertou o ataque e causou 1 de dano
# y ainda tem: 19 de vida
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# x errou o ataque
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# x errou o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# x errou o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y errou o ataque
# y defendeu o ataque
# x defendeu o ataque
# y defendeu o ataque
# y acertou o ataque e causou 8 de dano
# x ainda tem: -2 de vida
# y venceu com 19 de vida
